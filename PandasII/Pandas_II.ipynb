# %%
import pandas as pd

# %%
elections = pd.read_csv("elections.csv")

# %%
elections.iloc[[1, 2, 3], [0, 1, 2]]
# Out:
#    Year          Candidate        Party
# 1  1788         John Adams   Federalist
# 2  1792  George Washington  Independent
# 3  1792         John Adams   Federalist

# %%
elections.iloc[[1, 2, 3], 0:3]
# Out:
#    Year          Candidate        Party
# 1  1788         John Adams   Federalist
# 2  1792  George Washington  Independent
# 3  1792         John Adams   Federalist

# %%
elections.iloc[[1, 2, 3], 1]
# Out:
# 1           John Adams
# 2    George Washington
# 3           John Adams
# Name: Candidate, dtype: object

# %%
elections.iloc[0, 1]
# Out:
# 'George Washington'

# %%
elections[3:7]
# Out:
#    Year         Candidate                  Party  Popular vote Result     %
# 3  1792        John Adams             Federalist           NaN   loss   NaN
# 4  1796        John Adams             Federalist           NaN    win  53.4
# 5  1796  Thomas Jefferson  Democratic-Republican           NaN   loss  46.6
# 6  1800  Thomas Jefferson  Democratic-Republican           NaN    win  61.4

# %%
elections[["Year", "Candidate", "Result"]]
# Out:
#     Year          Candidate Result
# 0   1788  George Washington    win
# 1   1788         John Adams   loss
# 2   1792  George Washington    win
# 3   1792         John Adams   loss
# 4   1796         John Adams    win
# ..   ...                ...    ...
# 69  2020     Howard Hawkins   loss
# 70  2020       Joseph Biden    win
# 71  2020       Jo Jorgensen   loss
# 72  2024       Donald Trump    win
# 73  2024      Kamala Harris   loss
#
# [74 rows x 3 columns]

# %%
elections["Candidate"]
# Out:
# 0     George Washington
# 1            John Adams
# 2     George Washington
# 3            John Adams
# 4            John Adams
#             ...
# 69       Howard Hawkins
# 70         Joseph Biden
# 71         Jo Jorgensen
# 72         Donald Trump
# 73        Kamala Harris
# Name: Candidate, Length: 74, dtype: object

# %%
import zipfile
import os

zip_path = "/content/namesbystate.zip"  # Ensure the correct path
extract_path = "/content/namesbystate"  # Extract here

# Extract ZIP file
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

# Check extracted files
print(os.listdir(extract_path))  # Should list all state TXT files (CA.TXT, TX.TXT, etc.)
# Out:
# ['AK.TXT', 'NM.TXT', 'IA.TXT', 'ND.TXT', 'AL.TXT', 'GA.TXT', 'WV.TXT', 'WI.TXT', 'NC.TXT', 'NJ.TXT', 'OH.TXT', 'VT.TXT', 'AZ.TXT', 'PA.TXT', 'OK.TXT', 'DC.TXT', 'MI.TXT', 'CO.TXT', 'DE.TXT', 'MS.TXT', 'KS.TXT', 'IN.TXT', 'RI.TXT', 'SC.TXT', 'KY.TXT', 'CA.TXT', 'NE.TXT', 'TN.TXT', 'OR.TXT', 'MO.TXT', 'SD.TXT', 'CT.TXT', 'TX.TXT', 'IL.TXT', 'MA.TXT', 'MN.TXT', 'VA.TXT', 'ID.TXT', 'MD.TXT', 'HI.TXT', 'WA.TXT', 'MT.TXT', 'ME.TXT', 'NH.TXT', 'FL.TXT', 'LA.TXT', 'UT.TXT', 'NY.TXT', 'WY.TXT', 'StateReadMe.pdf', 'AR.TXT', 'NV.TXT']

# %%
import pandas as pd

# Define column names based on SSA TXT file format
columns = ["State", "Sex", "Year", "Name", "Count"]

# Initialize an empty DataFrame
babynames = pd.DataFrame(columns=columns)

# Loop through all TXT files in the extracted folder
for file in os.listdir(extract_path):
    if file.endswith(".TXT"):  # Ensure we only process TXT files
        file_path = os.path.join(extract_path, file)

        # Read the TXT file into a DataFrame
        state_df = pd.read_csv(file_path, header=None, names=columns)

        # Append data to the main DataFrame
        babynames = pd.concat([babynames, state_df], ignore_index=True)

# Show the first few rows of the combined DataFrame
babynames.head()
# Out:
#   State Sex  Year      Name Count
# 0    AK   F  1910      Mary    14
# 1    AK   F  1910     Annie    12
# 2    AK   F  1910      Anna    10
# 3    AK   F  1910  Margaret     8
# 4    AK   F  1910     Helen     7

# %%
babynames.info()  # Check dataset size and data types
babynames.tail()  # View the last few rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6504161 entries, 0 to 6504160
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   State   object
#  1   Sex     object
#  2   Year    object
#  3   Name    object
#  4   Count   object
# dtypes: object(5)
# memory usage: 248.1+ MB
#         State Sex  Year    Name Count
# 6504156    NV   M  2023   Zaire     5
# 6504157    NV   M  2023   Zakai     5
# 6504158    NV   M  2023    Zane     5
# 6504159    NV   M  2023  Zavier     5
# 6504160    NV   M  2023   Zyair     5

# %%
babynames_first_10_rows = babynames.iloc[:10]  # Use iloc instead of loc
print(babynames_first_10_rows)
# Out:
#   State Sex  Year      Name Count
# 0    AK   F  1910      Mary    14
# 1    AK   F  1910     Annie    12
# 2    AK   F  1910      Anna    10
# 3    AK   F  1910  Margaret     8
# 4    AK   F  1910     Helen     7
# 5    AK   F  1910     Elsie     6
# 6    AK   F  1910      Lucy     6
# 7    AK   F  1910   Dorothy     5
# 8    AK   F  1911      Mary    12
# 9    AK   F  1911  Margaret     7

# %%
babynames_first_10_rows[[True, False, True, False,
True, False, True, False, True, False]]
# Out:
#   State Sex  Year   Name Count
# 0    AK   F  1910   Mary    14
# 2    AK   F  1910   Anna    10
# 4    AK   F  1910  Helen     7
# 6    AK   F  1910   Lucy     6
# 8    AK   F  1911   Mary    12

# %%
babynames_first_10_rows.loc[[True, False, True, False, True, False, True,
False, True, False], :]
# Out:
#   State Sex  Year   Name Count
# 0    AK   F  1910   Mary    14
# 2    AK   F  1910   Anna    10
# 4    AK   F  1910  Helen     7
# 6    AK   F  1910   Lucy     6
# 8    AK   F  1911   Mary    12

# %%
logical_operator = (babynames["Sex"] == "F")
print(logical_operator)
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 6504156    False
# 6504157    False
# 6504158    False
# 6504159    False
# 6504160    False
# Name: Sex, Length: 6504161, dtype: bool

# %%
babynames[(babynames["Sex"] == "F")]
# Out:
#         State Sex  Year      Name Count
# 0          AK   F  1910      Mary    14
# 1          AK   F  1910     Annie    12
# 2          AK   F  1910      Anna    10
# 3          AK   F  1910  Margaret     8
# 4          AK   F  1910     Helen     7
# ...       ...  ..   ...       ...   ...
# 6479223    NV   F  2023    Taylor     5
# 6479224    NV   F  2023   Violeta     5
# 6479225    NV   F  2023    Yazmin     5
# 6479226    NV   F  2023     Zayla     5
# 6479227    NV   F  2023    Zaylee     5
#
# [3612034 rows x 5 columns]

# %%
babynames.loc[babynames["Sex"] == "F", :]
# Out:
#         State Sex  Year      Name Count
# 0          AK   F  1910      Mary    14
# 1          AK   F  1910     Annie    12
# 2          AK   F  1910      Anna    10
# 3          AK   F  1910  Margaret     8
# 4          AK   F  1910     Helen     7
# ...       ...  ..   ...       ...   ...
# 6479223    NV   F  2023    Taylor     5
# 6479224    NV   F  2023   Violeta     5
# 6479225    NV   F  2023    Yazmin     5
# 6479226    NV   F  2023     Zayla     5
# 6479227    NV   F  2023    Zaylee     5
#
# [3612034 rows x 5 columns]

# %%
babynames[(babynames["Sex"] == "F") | (babynames["Year"] < 2000)]
# Out:
#         State Sex  Year      Name Count
# 0          AK   F  1910      Mary    14
# 1          AK   F  1910     Annie    12
# 2          AK   F  1910      Anna    10
# 3          AK   F  1910  Margaret     8
# 4          AK   F  1910     Helen     7
# ...       ...  ..   ...       ...   ...
# 6491093    NV   M  1999   Tristen     5
# 6491094    NV   M  1999    Tucker     5
# 6491095    NV   M  1999    Tyrone     5
# 6491096    NV   M  1999      Wade     5
# 6491097    NV   M  1999   Zackery     5
#
# [5503316 rows x 5 columns]

# %%
babynames[(babynames["Name"] == "Bella") |
(babynames["Name"] == "Alex") |
(babynames["Name"] == "Narges") |
(babynames["Name"] == "Lisa")]
# Out:
#         State Sex  Year  Name Count
# 1820       AK   F  1954  Lisa    10
# 1926       AK   F  1955  Lisa    20
# 2112       AK   F  1956  Lisa    17
# 2273       AK   F  1957  Lisa    20
# 2465       AK   F  1958  Lisa    18
# ...       ...  ..   ...   ...   ...
# 6501383    NV   M  2019  Alex    30
# 6501955    NV   M  2020  Alex    33
# 6502601    NV   M  2021  Alex    18
# 6503100    NV   M  2022  Alex    31
# 6503705    NV   M  2023  Alex    24
#
# [9929 rows x 5 columns]

# %%
names = ["Bella", "Alex", "Narges", "Lisa"]
babynames[babynames["Name"].isin(names)]
# Out:
#         State Sex  Year  Name Count
# 1820       AK   F  1954  Lisa    10
# 1926       AK   F  1955  Lisa    20
# 2112       AK   F  1956  Lisa    17
# 2273       AK   F  1957  Lisa    20
# 2465       AK   F  1958  Lisa    18
# ...       ...  ..   ...   ...   ...
# 6501383    NV   M  2019  Alex    30
# 6501955    NV   M  2020  Alex    33
# 6502601    NV   M  2021  Alex    18
# 6503100    NV   M  2022  Alex    31
# 6503705    NV   M  2023  Alex    24
#
# [9929 rows x 5 columns]

# %%
babynames[babynames["Name"].str.startswith("N")]
# Out:
#         State Sex  Year       Name Count
# 240        AK   F  1923     Nellie     5
# 277        AK   F  1925      Norma     7
# 386        AK   F  1929      Nancy     6
# 411        AK   F  1930      Nancy     6
# 451        AK   F  1932      Nancy     8
# ...       ...  ..   ...        ...   ...
# 6504136    NV   M  2023  Nathanael     5
# 6504137    NV   M  2023   Nehemiah     5
# 6504138    NV   M  2023    Niklaus     5
# 6504139    NV   M  2023    Nikolai     5
# 6504140    NV   M  2023        Noa     5
#
# [166618 rows x 5 columns]

# %%
# this is to create a series of the length of each name
babynames_lengths = babynames["Name"].str.len()

#add the new column
babynames["name_lengths"] = babynames_lengths
print(babynames)
# Out:
#         State Sex  Year      Name Count  name_lengths
# 0          AK   F  1910      Mary    14             4
# 1          AK   F  1910     Annie    12             5
# 2          AK   F  1910      Anna    10             4
# 3          AK   F  1910  Margaret     8             8
# 4          AK   F  1910     Helen     7             5
# ...       ...  ..   ...       ...   ...           ...
# 6504156    NV   M  2023     Zaire     5             5
# 6504157    NV   M  2023     Zakai     5             5
# 6504158    NV   M  2023      Zane     5             4
# 6504159    NV   M  2023    Zavier     5             6
# 6504160    NV   M  2023     Zyair     5             5
#
# [6504161 rows x 6 columns]

# %%
babynames["name_lengths"] = babynames["name_lengths"]-1
print(babynames)
# Out:
#         State Sex  Year      Name Count  name_lengths
# 0          AK   F  1910      Mary    14             3
# 1          AK   F  1910     Annie    12             4
# 2          AK   F  1910      Anna    10             3
# 3          AK   F  1910  Margaret     8             7
# 4          AK   F  1910     Helen     7             4
# ...       ...  ..   ...       ...   ...           ...
# 6504156    NV   M  2023     Zaire     5             4
# 6504157    NV   M  2023     Zakai     5             4
# 6504158    NV   M  2023      Zane     5             3
# 6504159    NV   M  2023    Zavier     5             5
# 6504160    NV   M  2023     Zyair     5             4
#
# [6504161 rows x 6 columns]

# %%
#rename the column
babynames = babynames.rename(columns={"name_lengths": "Length"})

# %%
babynames = babynames.drop("Length", axis="columns")
print(babynames)
# Out:
#         State Sex  Year      Name Count
# 0          AK   F  1910      Mary    14
# 1          AK   F  1910     Annie    12
# 2          AK   F  1910      Anna    10
# 3          AK   F  1910  Margaret     8
# 4          AK   F  1910     Helen     7
# ...       ...  ..   ...       ...   ...
# 6504156    NV   M  2023     Zaire     5
# 6504157    NV   M  2023     Zakai     5
# 6504158    NV   M  2023      Zane     5
# 6504159    NV   M  2023    Zavier     5
# 6504160    NV   M  2023     Zyair     5
#
# [6504161 rows x 5 columns]

# %%
import numpy as np

yash_count = babynames[babynames["Name"]=="Yash"]["Count"]

print(yash_count)
# Out:
# 568621     6
# 569737     7
# 571258     5
# 573517     8
# 576841     5
#           ..
# 6290885    6
# 6293219    5
# 6297408    5
# 6298992    7
# 6311061    8
# Name: Count, Length: 165, dtype: object

# %%
babynames.shape
# Out:
# (6504161, 5)

# %%
babynames.size
# Out:
# 32520805

# %%
babynames.describe()
# Out:
#           State      Sex     Year     Name    Count
# count   6504161  6504161  6504161  6504161  6504161
# unique       51        2      114    33058     4942
# top          CA        F     2022    James        5
# freq     413894  3612034    95849     7519   839808

# %%
babynames["Sex"].describe()
# Out:
# count     6504161
# unique          2
# top             F
# freq      3612034
# Name: Sex, dtype: object

# %%
babynames.sample()
# Out:
#         State Sex  Year Name Count
# 6211681    NY   M  1960  Rob    11

# %%
babynames.sample(5).iloc[:, 2:]
# Out:
#          Year       Name Count
# 4936478  1944     Harvey    51
# 2415072  1975       Cari    12
# 4773573  2017  Katherine    38
# 6405416  1922      Finis    16
# 5294804  2011    Brianna    73

# %%
babynames[babynames["Year"] == 2000].sample(4, replace=True).iloc[:, 2:]
# Out:
#          Year      Name Count
# 4693647  2000  Henrique     6
# 3282091  2000     Asael     6
# 6118688  2000     Jamya     5
# 5697272  2000      Fred    12

# %%
babynames["Name"].value_counts()
# Out:
# Name
# James      7519
# Leslie     7455
# Lee        7371
# John       7322
# Robert     7274
#            ...
# Fowler        1
# Roe           1
# Paschal       1
# Lowry         1
# Malyn         1
# Name: count, Length: 33058, dtype: int64

# %%
babynames["Name"].unique()
# Out:
# array(['Mary', 'Annie', 'Anna', ..., 'Chaffee', 'Ausitn', 'Bb'],
#       dtype=object)

# %%
babynames["Name"].sort_values()
# Out:
# 6292735       Aaban
# 6294818       Aaban
# 6305118       Aadam
# 3321715       Aadan
# 3303709       Aadan
#              ...
# 4118997      Zyriah
# 4115667      Zyriah
# 4318201       Zyron
# 3342271       Zyrus
# 565240     Zyshonne
# Name: Name, Length: 6504161, dtype: object

# %%
babynames.sort_values(by = "Count", ascending = False)
# Out:
#         State Sex  Year     Name  Count
# 6199690    NY   M  1947   Robert  10027
# 6199691    NY   M  1947     John   9637
# 6198985    NY   M  1946   Robert   9295
# 6214127    NY   M  1963  Michael   9240
# 6209001    NY   M  1958  Michael   9226
# ...       ...  ..   ...      ...    ...
# 5525959    FL   F  1944   Amelia      5
# 5525960    FL   F  1944    Angie      5
# 5525961    FL   F  1944      Ava      5
# 5525962    FL   F  1944     Avis      5
# 6504160    NV   M  2023    Zyair      5
#
# [6504161 rows x 5 columns]

# %%
#create a temp column
babyname_length = babynames["Name"].str.len()
babynames["name_lengths"] = babynames_lengths
babynames = babynames.sort_values(by="name_lengths", ascending=False)
babynames.head(5)
# Out:
#         State Sex  Year             Name Count  name_lengths
# 3250248    CA   M  1987  Franciscojavier     5            15
# 3265064    CA   M  1993  Johnchristopher     5            15
# 3282148    CA   M  2000  Franciscojavier     6            15
# 3254589    CA   M  1989  Franciscojavier     6            15
# 3275185    CA   M  1997  Ryanchristopher     5            15

# %%
babynames.sort_values("Name", key=lambda x: x.str.len(), ascending=False).head()
# Out:
#         State Sex  Year             Name Count  name_lengths
# 3250248    CA   M  1987  Franciscojavier     5            15
# 3259496    CA   M  1991  Ryanchristopher     7            15
# 3251682    CA   M  1988  Franciscojavier    10            15
# 3036567    CA   F  1986  Mariadelosangel     5            15
# 3277180    CA   M  1998  Franciscojavier     6            15

# %%
def dr_ea_count(string):
  return string.count('dr') + string.count('ea')
babynames["dr_ea_count"] = babynames["Name"].map(dr_ea_count)
babynames = babynames.sort_values(by="dr_ea_count", ascending=False)
babynames.head()
# Out:
#         State Sex  Year      Name Count  name_lengths  dr_ea_count
# 3490518    TN   F  2009  Deandrea     6             8            3
# 4054403    TX   F  1985  Deandrea    15             8            3
# 4068627    TX   F  1991  Keandrea     7             8            3
# 4421284    IL   F  1991  Deandrea     7             8            3
# 4261213    TX   M  1989  Deandrea     5             8            3
